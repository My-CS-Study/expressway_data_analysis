# %%
# 8am adjacentMatrix concerning all the provinces
# this determines the width of edges
import pandas as pd
traffCombined = pd.read_csv('predict8amTraffic.csv')
traffCombined
# Out:
#   Unnamed: 0        서울경기         강원도         대전충남         충청북도         대구경북  \
# 0       서울경기     0.00000  77493.6365  21453.60700  48821.99350  17142.83550
# 1        강원도  5072.95250      0.0000    104.55000    953.25000    246.00000
# 2       대전충남  3552.46650     30.0420      0.00000   2216.74600    649.93600
# 3       충청북도  2854.30850    335.8010    676.54025      0.00000    610.56600
# 4       대구경북   345.40450     42.1225   6192.00750    252.73500      0.00000
# 5       전라북도   106.19100      9.2340    775.65600    106.19100    108.49950
# 6       광주전남   276.10125     18.1050    977.67000    140.31375    248.94375
# 7       부산경남  4045.79700     32.1095   3146.73100    369.25925   6437.95475
#
#          전라북도       광주전남        부산경남
# 0  5012.52500  6516.2825  17443.5870
# 1    36.90000    36.9000     12.3000
# 2  1566.81000  2564.9260   1241.8420
# 3   216.97800   146.3340    206.8860
# 4   558.37650   753.1590   6661.5615
# 5     0.00000  1488.1830    162.2190
# ...

# %%
traffCombined = traffCombined.rename(columns={'Unnamed: 0':'name'})
traffCombined = traffCombined.set_index('name')
traffCombined.head()
# Out:
#            서울경기         강원도         대전충남        충청북도        대구경북       전라북도  \
# name
# 서울경기     0.0000  77493.6365  21453.60700  48821.9935  17142.8355  5012.5250
# 강원도   5072.9525      0.0000    104.55000    953.2500    246.0000    36.9000
# 대전충남  3552.4665     30.0420      0.00000   2216.7460    649.9360  1566.8100
# 충청북도  2854.3085    335.8010    676.54025      0.0000    610.5660   216.9780
# 대구경북   345.4045     42.1225   6192.00750    252.7350      0.0000   558.3765
#
#            광주전남        부산경남
# name
# 서울경기  6516.2825  17443.5870
# 강원도     36.9000     12.3000
# 대전충남  2564.9260   1241.8420
# 충청북도   146.3340    206.8860
# 대구경북   753.1590   6661.5615

# %%
traffCombined
# Out:
#             서울경기         강원도         대전충남         충청북도         대구경북  \
# name
# 서울경기     0.00000  77493.6365  21453.60700  48821.99350  17142.83550
# 강원도   5072.95250      0.0000    104.55000    953.25000    246.00000
# 대전충남  3552.46650     30.0420      0.00000   2216.74600    649.93600
# 충청북도  2854.30850    335.8010    676.54025      0.00000    610.56600
# 대구경북   345.40450     42.1225   6192.00750    252.73500      0.00000
# 전라북도   106.19100      9.2340    775.65600    106.19100    108.49950
# 광주전남   276.10125     18.1050    977.67000    140.31375    248.94375
# 부산경남  4045.79700     32.1095   3146.73100    369.25925   6437.95475
#
#             전라북도       광주전남        부산경남
# name
# 서울경기  5012.52500  6516.2825  17443.5870
# 강원도     36.90000    36.9000     12.3000
# 대전충남  1566.81000  2564.9260   1241.8420
# 충청북도   216.97800   146.3340    206.8860
# 대구경북   558.37650   753.1590   6661.5615
# 전라북도     0.00000  1488.1830    162.2190
# 광주전남  1842.18375     0.0000    759.9200
# ...

# %%
len(traffCombined.keys())
# Out:
# 8

# %%
traffCombined['서울경기']
# Out:
# name
# 서울경기       0.00000
# 강원도     5072.95250
# 대전충남    3552.46650
# 충청북도    2854.30850
# 대구경북     345.40450
# 전라북도     106.19100
# 광주전남     276.10125
# 부산경남    4045.79700
# Name: 서울경기, dtype: float64

# %%
traffCombined.iloc[0][1]
# Out:
# C:\Users\syj43\AppData\Local\Temp\ipykernel_6644\1387104519.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   traffCombined.iloc[0][1]
# np.float64(77493.63650000001)

# %%
# to get a list for edge color
edgeColorList = []

for i in range(len(traffCombined.keys())):
    for j in range(len(traffCombined.keys())):
        if i==j:
            continue
        else:
            edgeColorList.append(int(traffCombined.iloc[i][j]))

edgeColorList
# Out:
# C:\Users\syj43\AppData\Local\Temp\ipykernel_6644\4084266966.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   edgeColorList.append(int(traffCombined.iloc[i][j]))
# [77493,
#  21453,
#  48821,
#  17142,
#  5012,
#  6516,
#  17443,
#  5072,
#  104,
#  953,
#  246,
#  36,
#  36,
#  12,
#  3552,
#  30,
#  2216,
#  649,
#  1566,
#  2564,
#  1241,
#  2854,
#  335,
#  676,
#  610,
#  216,
#  146,
#  206,
#  345,
#  42,
#  6192,
#  252,
#  558,
#  753,
#  6661,
#  106,
#  9,
#  775,
#  106,
#  108,
#  1488,
#  162,
#  276,
#  18,
#  977,
#  140,
#  248,
#  1842,
#  759,
#  4045,
#  32,
#  3146,
#  369,
#  6437,
#  594,
#  1444]

# %%
len(edgeColorList)
# Out:
# 56

# %%
sorted(edgeColorList)
# Out:
# [9,
#  12,
#  18,
#  30,
#  32,
#  36,
#  36,
#  42,
#  104,
#  106,
#  106,
#  108,
#  140,
#  146,
#  162,
#  206,
#  216,
#  246,
#  248,
#  252,
#  276,
#  335,
#  345,
#  369,
#  558,
#  594,
#  610,
#  649,
#  676,
#  753,
#  759,
#  775,
#  953,
#  977,
#  1241,
#  1444,
#  1488,
#  1566,
#  1842,
#  2216,
#  2564,
#  2854,
#  3146,
#  3552,
#  4045,
#  5012,
#  5072,
#  6192,
#  6437,
#  6516,
#  6661,
#  17142,
#  17443,
#  21453,
#  48821,
#  77493]

# %%
# distribution of traffic
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.displot(edgeColorList) 
plt.xlabel('traffic')
plt.ylabel('count')
plt.title('Distribution of traffic at 8am')
plt.show() # ~ normalized

# %%
import matplotlib.font_manager as fm
fm.fontManager.addfont('BinggraeII.ttf')

# %%
import networkx as nx
G = nx.from_pandas_adjacency(traffCombined)
pos = nx.circular_layout(G)
nx.draw_networkx(G, pos=pos, font_family='Binggrae?')

# %%
G.nodes()
# Out:
# NodeView(('서울경기', '강원도', '대전충남', '충청북도', '대구경북', '전라북도', '광주전남', '부산경남'))

# %%
G.edges()
# Out:
# EdgeView([('서울경기', '강원도'), ('서울경기', '대전충남'), ('서울경기', '충청북도'), ('서울경기', '대구경북'), ('서울경기', '전라북도'), ('서울경기', '광주전남'), ('서울경기', '부산경남'), ('강원도', '대전충남'), ('강원도', '충청북도'), ('강원도', '대구경북'), ('강원도', '전라북도'), ('강원도', '광주전남'), ('강원도', '부산경남'), ('대전충남', '충청북도'), ('대전충남', '대구경북'), ('대전충남', '전라북도'), ('대전충남', '광주전남'), ('대전충남', '부산경남'), ('충청북도', '대구경북'), ('충청북도', '전라북도'), ('충청북도', '광주전남'), ('충청북도', '부산경남'), ('대구경북', '전라북도'), ('대구경북', '광주전남'), ('대구경북', '부산경남'), ('전라북도', '광주전남'), ('전라북도', '부산경남'), ('광주전남', '부산경남')])

# %%
# node list ordered in the desired way
nodeList = ['대구경북','강원도','서울경기','충청북도','대전충남','전라북도','광주전남','광주전남','부산경남']

# %%
edgeList = [('서울경기', '강원도'), ('서울경기', '대전충남'), ('서울경기', '충청북도'), ('서울경기', '대구경북'), ('서울경기', '전라북도'), ('서울경기', '광주전남'), ('서울경기', '부산경남'), 
            ('강원도', '서울경기'),('강원도', '대전충남'), ('강원도', '충청북도'), ('강원도', '대구경북'), ('강원도', '전라북도'), ('강원도', '광주전남'), ('강원도', '부산경남'), 
            ('대전충남', '서울경기'),('대전충남', '강원도'),('대전충남', '충청북도'), ('대전충남', '대구경북'), ('대전충남', '전라북도'), ('대전충남', '광주전남'), ('대전충남', '부산경남'), 
            ('충청북도', '서울경기'),('충청북도', '강원도'),('충청북도', '대전충남'),('충청북도', '대구경북'), ('충청북도', '전라북도'), ('충청북도', '광주전남'), ('충청북도', '부산경남'), 
            ('대구경북', '서울경기'),('대구경북', '강원도'),('대구경북', '대전충남'),('대구경북', '충청북도'),('대구경북', '전라북도'), ('대구경북', '광주전남'), ('대구경북', '부산경남'), 
            ('전라북도', '서울경기'),('전라북도', '강원도'),('전라북도', '대전충남'),('전라북도', '충청북도'),('전라북도', '대구경북'),('전라북도', '광주전남'), ('전라북도', '부산경남'), 
            ('광주전남', '서울경기'),('광주전남', '강원도'),('광주전남', '대전충남'),('광주전남', '충청북도'),('광주전남', '대구경북'),('광주전남', '전라북도'),('광주전남', '부산경남'),
           ('부산경남','서울경기'),('부산경남','강원도'),('부산경남','대전충남'),('부산경남','충청북도'),('부산경남','대구경북'),('부산경남','전라북도'),('부산경남','광주전남')]

# %%
len(edgeList)
# Out:
# 56

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1,1)
G = nx.Graph()
mpl.rcParams["font.family"] = 'Binggrae?'
cmap = plt.cm.RdPu
G.add_nodes_from(nodeList)
pos = nx.circular_layout(G)
nodes = nx.draw_networkx_nodes(G, pos, node_size=500, node_color='#FCE6EE')
nx.draw_networkx_labels(G,pos,labels={i:i for i in nodeList},font_family='Binggrae?')
edges = nx.draw_networkx_edges(
    G,
    pos,
    edgelist=edgeList,
    arrows=True,
    arrowstyle="->",
    connectionstyle='arc3,rad=0.1', # rad=0.1
    arrowsize=20,
    width=2,
    # edge_color=list(edge_colors),
    edge_color=edgeColorList,
    edge_vmin=0,
    edge_vmax=80000,
    edge_cmap=cmap
)

pc = mpl.collections.PatchCollection(edges, cmap=cmap)
pc.set_array(edgeColorList)

ax = plt.gca()
ax.set_axis_off()
# norm = mpl.colors.Normalize(vmin=5, vmax=80)
# fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmapTraffic),
#              ax=ax, orientation='vertical', label='하루 평균 교통량 (천)', fraction=0.07, pad=0.05, location='left')
plt.colorbar(pc, ax=ax, label='교통량 (대)')
plt.title('평일 출근시간 평균 통행량', fontsize=18)
plt.show()

# %%
print(len(list(edge_colors)))
print(len(G.edges()))
# Out:
# 30
# 28

# %% [markdown]
# # customize arrow style
# set_connectionstyle("Arc,armA=30,rad=10")
# set_connectionstyle("arc", armA=30, rad=10)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx

seed = 13648  # Seed random number generators for reproducibility
G = nx.random_k_out_graph(10, 3, 0.5, seed=seed)
pos = nx.spring_layout(G, seed=seed)

node_sizes = [3 + 10 * i for i in range(len(G))]
M = G.number_of_edges()
edge_colors = range(2, M + 2) ###
edge_alphas = [(5 + i) / (M + 4) for i in range(M)]
cmap = plt.cm.plasma

nodes = nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color="indigo")
edges = nx.draw_networkx_edges(
    G,
    pos,
    node_size=node_sizes,
    arrowstyle="->",
    arrowsize=10,
    edge_color=list(edge_colors), ###
    edge_cmap=cmap, ###
    width=2,
)
# set alpha value for each edge
for i in range(M):
    edges[i].set_alpha(edge_alphas[i])

pc = mpl.collections.PatchCollection(edges, cmap=cmap) ###
pc.set_array(edge_colors) ###

ax = plt.gca()
ax.set_axis_off()
plt.colorbar(pc, ax=ax)
plt.show()

# %%
sortedEdgeColorList = sorted(edgeColorList)
sortedEdgeColorList = np.array(sortedEdgeColorList)
sortedEdgeColorList = np.round(sortedEdgeColorList/1000,3)
sortedEdgeColorList = sortedEdgeColorList.tolist()
sortedEdgeColorList
# Out:
# [0.009,
#  0.012,
#  0.018,
#  0.03,
#  0.032,
#  0.036,
#  0.036,
#  0.042,
#  0.104,
#  0.106,
#  0.106,
#  0.108,
#  0.14,
#  0.146,
#  0.162,
#  0.206,
#  0.216,
#  0.246,
#  0.248,
#  0.252,
#  0.276,
#  0.335,
#  0.345,
#  0.369,
#  0.558,
#  0.594,
#  0.61,
#  0.649,
#  0.676,
#  0.753,
#  0.759,
#  0.775,
#  0.953,
#  0.977,
#  1.241,
#  1.444,
#  1.488,
#  1.566,
#  1.842,
#  2.216,
#  2.564,
#  2.854,
#  3.146,
#  3.552,
#  4.045,
#  5.012,
#  5.072,
#  6.192,
#  6.437,
#  6.516,
#  6.661,
#  17.142,
#  17.443,
#  21.453,
#  48.821,
#  77.493]

# %%
G = nx.Graph()
mpl.rcParams["font.family"] = 'Binggrae?'
cmap = plt.cm.RdPu
G.add_nodes_from(nodeList)
pos = nx.circular_layout(G)
nodes = nx.draw_networkx_nodes(G, pos, node_size=500, node_color='#FCE6EE')
nx.draw_networkx_labels(G,pos,labels={i:i for i in nodeList},font_family='Binggrae?')
edges = nx.draw_networkx_edges(
    G,
    pos,
    edgelist=,
    arrows=True,
    arrowstyle="->",
    connectionstyle='arc3', # rad=0.1
    arrowsize=20,
    width=2,
    # edge_color=list(edge_colors),
    edge_color=sortedEdgeColorList[-10:],
    edge_vmin=5,
    edge_vmax=80,
    edge_cmap=cmap
)

pc = mpl.collections.PatchCollection(edges, cmap=cmap)
pc.set_array(edgeColorList)

ax = plt.gca()
ax.set_axis_off()
# norm = mpl.colors.Normalize(vmin=5, vmax=80)
# fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmapTraffic),
#              ax=ax, orientation='vertical', label='하루 평균 교통량 (천)', fraction=0.07, pad=0.05, location='left')
plt.colorbar(pc, ax=ax, label='교통량 (천 대)')
plt.title('평일 출근시간 평균 통행량', fontsize=18)
plt.show()
